# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings("ignore")
import os.path
import os,re
import glob
import pprint
import pathlib
import threading
import time
import joblib
from pandas import DataFrame
from datetime import datetime,timedelta
import datetime
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
import joblib
from tensorflow import keras
from sklearn.utils import shuffle

# %% [markdown]
# ### Extracting Images

# %%
file_destination = r'C:\Users\SM-PC\BDJ\BDJ_Spectrogram_deep\sp1'
import cv2

image_w = 32
image_h = 32

X = []
Y = []
for f in glob.glob(file_destination + "/*.jpg"):
    img = cv2.imread(f)
    img = cv2.resize(img, (image_w, image_h))
    X.append(img)

# %%
ls = []
for f in os.listdir(file_destination):
#      print((f.split('_')[0:2][0])+'_'+(f.split('_')[0:2][1]))
#     print(f.split('_')[0])
     labels = (f.split('_')[0:2][0])+'_'+(f.split('_')[0:2][1])
     ls.append(labels)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(ls)
label = encoder.transform(ls)
# print the decoded labels
encoder.inverse_transform(label)
# Out:
# array(['axis_11', 'axis_11', 'axis_11', ..., 'rotating_5d5',
#        'rotating_5d5', 'rotating_5d5'], dtype='<U12')

# %%
from keras.utils import np_utils
label_cat = np_utils.to_categorical(label)

# %%
X = np.array(X)
Y = np.array(label_cat)
# print(X,Y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,
                                                    shuffle=True,
                                                    stratify=Y,test_size=0.3,
                                                    random_state = 222)
xy = (X_train, X_test, y_train, y_test)

X_train = X_train.astype("float") / 255.0
X_test  = X_test.astype("float")  / 255.0
print('X_train shape:', X_train.shape)
# Out:
# X_train shape: (30094, 32, 32, 3)

# %% [markdown]
# ### CNN

# %%
from keras.models import Sequential,Model
from keras.layers import MaxPooling2D,MaxPooling3D,UpSampling2D,Input,Conv2DTranspose
from keras.layers import Conv2D,Conv3D
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.layers import BatchNormalization, Dropout

# %%
def hist(hist):
    
    fig, loss_ax = plt.subplots()
    acc_ax = loss_ax.twinx()

    loss_ax.plot(hist.history['loss'], 'y', label='train loss')
    loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

    acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
    acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')
    acc_ax.set_ylabel('accuray')
    
    acc_ax.set_ylim(0.6,0.83)
    
    loss_ax.legend(bbox_to_anchor=(-0.1,0.15))
    acc_ax.legend(bbox_to_anchor=(1.35,1))

    plt.show()

# %%
# Define the input shape
input_shape = (32, 32, 3)  # Assuming the input image size is 28x28 with 1 channel

# Define the CNN architecture
model2 = tf.keras.Sequential([
    # Image Block
    Conv2D(filters=50, kernel_size=5, activation='relu', padding='same', input_shape=input_shape),
    Conv2D(filters=50, kernel_size=5, activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
#     Dropout(0.25),
    Conv2D(filters=100, kernel_size=5, activation='relu', padding='same'),
    Conv2D(filters=100, kernel_size=5, activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
#     Dropout(0.25),

    # Classification Head
    Flatten(),
    Dense(units=43, activation='softmax')
])

# Compile the model with the given optimizer and learning rate
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.001)
model2.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 50)        3800
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 50)        62550
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 50)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 100)       125100
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 100)       250100
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 100)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 43)                275243
#
# =================================================================
# Total params: 716,793
# Trainable params: 716,793
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit(X_train,y_train,validation_data=(X_test,y_test),
       batch_size = 16,epochs=100)
# Out:
# Epoch 1/100
# 1881/1881 [==============================] - 12s 5ms/step - loss: 0.6294 - accuracy: 0.7382 - val_loss: 0.2813 - val_accuracy: 0.8138
# Epoch 2/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2869 - accuracy: 0.8092 - val_loss: 0.2713 - val_accuracy: 0.8087
# Epoch 3/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2810 - accuracy: 0.8081 - val_loss: 0.3185 - val_accuracy: 0.7990
# Epoch 4/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2727 - accuracy: 0.8124 - val_loss: 0.3061 - val_accuracy: 0.8009
# Epoch 5/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2725 - accuracy: 0.8101 - val_loss: 0.3346 - val_accuracy: 0.8087
# Epoch 6/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2712 - accuracy: 0.8154 - val_loss: 0.2635 - val_accuracy: 0.8104
# Epoch 7/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2688 - accuracy: 0.8126 - val_loss: 0.2740 - val_accuracy: 0.8121
# Epoch 8/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2681 - accuracy: 0.8119 - val_loss: 0.2656 - val_accuracy: 0.8112
# Epoch 9/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.
100
# 1881/1881 [==============================] - 9s 5ms/step - loss: 0.2605 - accuracy: 0.8127 - val_loss: 0.2632 - val_accuracy: 0.8083
# Epoch 75/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2646 - accuracy: 0.8102 - val_loss: 0.2643 - val_accuracy: 0.8089
# Epoch 76/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2598 - accuracy: 0.8156 - val_loss: 0.2716 - val_accuracy: 0.8048
# Epoch 77/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2600 - accuracy: 0.8135 - val_loss: 0.2633 - val_accuracy: 0.8055
# Epoch 78/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2623 - accuracy: 0.8129 - val_loss: 0.2640 - val_accuracy: 0.8073
# Epoch 79/100
# 1881/1881 [==============================] - 9s 5ms/step - loss: 0.2620 - accuracy: 0.8141 - val_loss: 0.2704 - val_accuracy: 0.8018
# Epoch 80/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2598 - accuracy: 0.8149 - val_loss: 0.2644 - val_accuracy: 0.8050
# Epoch 81/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2594 - accuracy: 0.8144 - val_loss: 0.2717 - val_accuracy: 0.8073
# Epoch 82/100
# 1881/1881 [==============================] - 9s 5ms/step - loss: 0.2631 - accuracy: 0.8089 - val_loss: 0.2650 - val_accuracy: 0.8077
# Epoch 83/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2608 - accuracy: 0.8155 - val_loss: 0.2697 - val_accuracy: 0.8031
# Epoch 84/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2614 - accuracy: 0.8137 - val_loss: 0.2655 - val_accuracy: 0.8042
# Epoch 85/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2612 - accuracy: 0.8139 - val_loss: 0.2643 - val_accuracy: 0.8079
# Epoch 86/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2619 - accuracy: 0.8122 - val_loss: 0.2640 - val_accuracy: 0.8083
# Epoch 87/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2617 - accuracy: 0.8150 - val_loss: 0.2692 - val_accuracy: 0.8097
# Epoch 88/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2616 - accuracy: 0.8127 - val_loss: 0.2655 - val_accuracy: 0.8047
# Epoch 89/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2611 - accuracy: 0.8138 - val_loss: 0.2663 - val_accuracy: 0.8027
# Epoch 90/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2613 - accuracy: 0.8125 - val_loss: 0.3362 - val_accuracy: 0.7953
# Epoch 91/100
# 1881/1881 [==============================] - 9s 5ms/step - loss: 0.2616 - accuracy: 0.8115 - val_loss: 0.2653 - val_accuracy: 0.8069
# Epoch 92/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2612 - accuracy: 0.8142 - val_loss: 0.2672 - val_accuracy: 0.8041
# Epoch 93/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2595 - accuracy: 0.8127 - val_loss: 0.2648 - val_accuracy: 0.8061
# Epoch 94/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2610 - accuracy: 0.8165 - val_loss: 0.2656 - val_accuracy: 0.8058
# Epoch 95/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2607 - accuracy: 0.8150 - val_loss: 0.2691 - val_accuracy: 0.8068
# Epoch 96/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2610 - accuracy: 0.8144 - val_loss: 0.2648 - val_accuracy: 0.8074
# Epoch 97/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2621 - accuracy: 0.8147 - val_loss: 0.2692 - val_accuracy: 0.8064
# Epoch 98/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2602 - accuracy: 0.8115 - val_loss: 0.2680 - val_accuracy: 0.8041
# Epoch 99/100
# 1881/1881 [==============================] - 8s 4ms/step - loss: 0.2648 - accuracy: 0.8137 - val_loss: 0.2673 - val_accuracy: 0.8037
# Epoch 100/100
# 1881/1881 [==============================] - 9s 5ms/step - loss: 0.2605 - accuracy: 0.8138 - val_loss: 0.2665 - val_accuracy: 0.8040

# %%
model2.evaluate(X_train,y_train)
# Out:
# 941/941 [==============================] - 2s 2ms/step - loss: 0.2583 - accuracy: 0.8182
# [0.2582564651966095, 0.8182029724121094]

# %%
model2.evaluate(X_test,y_test)
# Out:
# 404/404 [==============================] - 1s 3ms/step - loss: 0.2665 - accuracy: 0.8040
# [0.26651623845100403, 0.8040006160736084]

# %%
model2.save('BDJ_CNN_Models/history2.h5')

# %%
hist(history2)

# %%
from keras.utils import plot_model
from tensorflow.keras.utils import plot_model

plot_model(model2, to_file="BDJ_CNN_ModelArchitecture/model2.png", show_shapes=True)
