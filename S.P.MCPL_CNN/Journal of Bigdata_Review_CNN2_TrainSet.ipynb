# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings("ignore")
import os.path
import os,re
import glob
import pprint
import pathlib
import threading
import time
import joblib
from pandas import DataFrame
from datetime import datetime,timedelta
import datetime
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
import joblib
from tensorflow import keras
from sklearn.utils import shuffle

# %% [markdown]
# ### Extracting Images

# %%
import tensorflow as tf
import numpy as np
import random
import os

def my_seed_everywhere(seed: int = 42):
    random.seed(seed) # random
    np.random.seed(seed) # np
    os.environ["PYTHONHASHSEED"] = str(seed) # os
    tf.random.set_seed(seed) # tensorflow

my_seed = 42
my_seed_everywhere(my_seed)

# %%
file_destination = r'C:\Users\SM-PC\BDJ\BDJ_S.P.MCPL_CNN\BDJ_Spectrogram_deep\sp1'
import cv2

image_w = 32
image_h = 32

X = []
Y = []
for f in glob.glob(file_destination + "/*.jpg"):
    img = cv2.imread(f)
    img = cv2.resize(img, (image_w, image_h))
    X.append(img)

# %%
ls = []
for f in os.listdir(file_destination):
#      print((f.split('_')[0:2][0])+'_'+(f.split('_')[0:2][1]))
#     print(f.split('_')[0])
     labels = (f.split('_')[0:2][0])+'_'+(f.split('_')[0:2][1])
     ls.append(labels)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(ls)
label = encoder.transform(ls)
# print the decoded labels
encoder.inverse_transform(label)
# Out:
# array(['axis_11', 'axis_11', 'axis_11', ..., 'rotating_5d5',
#        'rotating_5d5', 'rotating_5d5'], dtype='<U12')

# %%
from keras.utils import np_utils
label_cat = np_utils.to_categorical(label)

# %%
X = np.array(X)
Y = np.array(label_cat)
# print(X,Y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,
                                                    shuffle=True,
                                                    stratify=Y,test_size=0.3,
                                                    random_state = 666)
xy = (X_train, X_test, y_train, y_test)

X_train = X_train.astype("float") / 255.0
X_test  = X_test.astype("float")  / 255.0
print('X_train shape:', X_train.shape)
# Out:
# X_train shape: (30094, 32, 32, 3)

# %% [markdown]
# ### CNN2

# %%
from keras.models import Sequential,Model
from keras.layers import MaxPooling2D,MaxPooling3D,UpSampling2D,Input,Conv2DTranspose
from keras.layers import Conv2D,Conv3D
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.layers import BatchNormalization, Dropout

# %%
def hist(hist):
    
    fig, loss_ax = plt.subplots()
    acc_ax = loss_ax.twinx()

    loss_ax.plot(hist.history['loss'], 'y', label='train loss')
    loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

    acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
    acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

    loss_ax.set_xlabel('epoch')
    loss_ax.set_ylabel('loss')
    acc_ax.set_ylabel('accuray')

#     acc_ax.set_ylim(0.6,0.83)
#     loss_ax.set_ylim(0.25,0.3)
    acc_ax.set_ylim(0.6,0.83)
    loss_ax.legend(bbox_to_anchor=(-0.1,0.15))
    acc_ax.legend(bbox_to_anchor=(1.35,1))

    plt.show()

# %%
# Define the input shape
input_shape = (32, 32, 3)  # Assuming the input image size is 28x28 with 1 channel

# Define the CNN architecture
model6 = tf.keras.Sequential([
    # Image Block
    Conv2D(filters=32, kernel_size=5, activation='relu', padding='same', input_shape=input_shape),
    Conv2D(filters=32, kernel_size=5, activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
#     Dropout(0.25),
    Conv2D(filters=64, kernel_size=5, activation='relu', padding='same'),
    Conv2D(filters=64, kernel_size=5, activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
#     Dropout(0.25),

    # Classification Head
    Flatten(),
    Dense(units=43, activation='softmax')
])

# Compile the model with the given optimizer and learning rate
# optimizer = tf.keras.optimizers.Nadam(learning_rate=0.001)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model6.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model6.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        2432
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        25632
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        51264
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        102464
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 43)                176171
#
# =================================================================
# Total params: 357,963
# Trainable params: 357,963
# Non-trainable params: 0
# _________________________________________________________________

# %%
history6 = model6.fit(X_train,y_train,validation_data=(X_test,y_test),
       batch_size = 16,epochs=100)
# Out:
# Epoch 1/100
# 1881/1881 [==============================] - 8s 3ms/step - loss: 0.7105 - accuracy: 0.7195 - val_loss: 0.3034 - val_accuracy: 0.8014
# Epoch 2/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2887 - accuracy: 0.8076 - val_loss: 0.2829 - val_accuracy: 0.8079
# Epoch 3/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2823 - accuracy: 0.8068 - val_loss: 0.2724 - val_accuracy: 0.8118
# Epoch 4/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2730 - accuracy: 0.8133 - val_loss: 0.2686 - val_accuracy: 0.8130
# Epoch 5/100
# 1881/1881 [==============================] - 6s 3ms/step - loss: 0.2733 - accuracy: 0.8111 - val_loss: 0.2716 - val_accuracy: 0.8104
# Epoch 6/100
# 1881/1881 [==============================] - 6s 3ms/step - loss: 0.2746 - accuracy: 0.8102 - val_loss: 0.2650 - val_accuracy: 0.8111
# Epoch 7/100
# 1881/1881 [==============================] - 6s 3ms/step - loss: 0.2736 - accuracy: 0.8112 - val_loss: 0.2675 - val_accuracy: 0.8100
# Epoch 8/100
# 1881/1881 [==============================] - 6s 3ms/step - loss: 0.2695 - accuracy: 0.8108 - val_loss: 0.2758 - val_accuracy: 0.8089
# Epoch 9/100
# 1881/1881 [==============================] - 6s 3ms/step - loss: 0.2669 - accuracy: 0.8108 - val_loss: 0.2655 - val_accuracy: 0.8096
# Epoch 10/100
# 1881/1881 [==============================] - 6s 3ms/step - loss: 0.2679 - accuracy: 0.8112 - val_loss: 0.2681 - val_accuracy: 0.8106
# Epoch 11/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2663 - accuracy: 0.8129 - val_loss: 0.2650 - val_accuracy: 0.8098
# Epoch 12/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2688 - accuracy: 0.8095 - val_loss: 0.2630 - val_accuracy: 0.8116
# Epoch 13/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2654 - accuracy: 0.8102 - val_loss: 0.2734 - val_accuracy: 0.8062
# Epoch 14/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2647 - accuracy: 0.8098 - val_loss: 0.2635 - val_accuracy: 0.8128
# Epoch 15/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2682 - accuracy: 0.8125 - val_loss: 0.2821 - val_accuracy: 0.8084
# Epoch 16/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2657 - accuracy: 0.8107 - val_loss: 0.2687 - val_accuracy: 0.8114
# Epoch 17/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2645 - accuracy: 0.8111 - val_loss: 0.2627 - val_accuracy: 0.8084
# Epoch 18/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2659 - accuracy: 0.8096 - val_loss: 0.2635 - val_accuracy: 0.8085
# Epoch 19/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2670 - accuracy: 0.8121 - val_loss: 0.2653 - val_accuracy: 0.8086
# Epoch 20/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2622 - accuracy: 0.8138 - val_loss: 0.2628 - val_accuracy: 0.8067
# Epoch 21/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2663 - accuracy: 0.8138 - val_loss: 0.2671 - val_accuracy: 0.8083
# Epoch 22/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2644 - accuracy: 0.8139 - val_loss: 0.2615 - val_accuracy: 0.8083
# Epoch 23/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2653 - accuracy: 0.8147 - val_loss: 0.2622 - val_accuracy: 0.8066
# Epoch 24/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2675 - accuracy: 0.8100 - val_loss: 0.2664 - val_accuracy: 0.8076
# Epoch 25/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2642 - accuracy: 0.8117 - val_loss: 0.2641 - val_accuracy: 0.8088
# Epoch 26/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2634 - accuracy: 0.8093 - val_loss: 0.2628 - val_accuracy: 0.8062
# Epoch 27/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2657 - accuracy: 0.8118 - val_loss: 0.2640 - val_accuracy: 0.8091
# Epoch 28/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2632 - accuracy: 0.8098 - val_loss: 0.2626 - val_accuracy: 0.8059
# Epoch 29/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2727 - accuracy: 0.8126 - val_loss: 0.2645 - val_accuracy: 0.8064
# Epoch 30/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2636 - accuracy: 0.8140 - val_loss: 0.2661 - val_accuracy: 0.8097
# Epoch 31/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.
100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2619 - accuracy: 0.8163 - val_loss: 0.2659 - val_accuracy: 0.8014
# Epoch 92/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2619 - accuracy: 0.8138 - val_loss: 0.2657 - val_accuracy: 0.8069
# Epoch 93/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2592 - accuracy: 0.8139 - val_loss: 0.2644 - val_accuracy: 0.8039
# Epoch 94/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2646 - accuracy: 0.8097 - val_loss: 0.2692 - val_accuracy: 0.8018
# Epoch 95/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2627 - accuracy: 0.8120 - val_loss: 0.2647 - val_accuracy: 0.8049
# Epoch 96/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2619 - accuracy: 0.8154 - val_loss: 0.2660 - val_accuracy: 0.8069
# Epoch 97/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2601 - accuracy: 0.8164 - val_loss: 0.2653 - val_accuracy: 0.8079
# Epoch 98/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2614 - accuracy: 0.8140 - val_loss: 0.2683 - val_accuracy: 0.8074
# Epoch 99/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2632 - accuracy: 0.8129 - val_loss: 0.2648 - val_accuracy: 0.8067
# Epoch 100/100
# 1881/1881 [==============================] - 5s 3ms/step - loss: 0.2595 - accuracy: 0.8116 - val_loss: 0.2639 - val_accuracy: 0.8050

# %%
model6.evaluate(X_train,y_train)
# Out:
# 941/941 [==============================] - 2s 2ms/step - loss: 0.2585 - accuracy: 0.8177
# [0.2585415542125702, 0.8176712989807129]

# %%
model6.evaluate(X_test,y_test)
# Out:
# 404/404 [==============================] - 1s 2ms/step - loss: 0.2670 - accuracy: 0.8084
# [0.26695939898490906, 0.8084198832511902]

# %%
model6.save('BDJ_CNN_Models/history6.h5')

# %%
hist(history6)

# %%
from keras.utils import plot_model
from tensorflow.keras.utils import plot_model

plot_model(model6, to_file="BDJ_CNN_ModelArchitecture/model6.png", show_shapes=True)

# %%
from keras.models import load_model
model6_load = keras.models.load_model("BDJ_CNN_Models/history6.h5")

# %%
pred6 = model6_load.predict(X_test)
# Out:
# 404/404 [==============================] - 1s 2ms/step

# %% [markdown]
# ### ConfusionMatrix

# %%
from sklearn.metrics import confusion_matrix
def confusionMatrix(pred,y_test,label):
    y_pred_arg = np.argmax(pred,axis=1)
    y_test_arg = np.argmax(y_test,axis=1)
    cm = confusion_matrix(y_pred_arg,y_test_arg)
    cm_df = DataFrame(cm)
    cm_label = DataFrame(encoder.inverse_transform(label))[0].unique()
    cm_df.columns=cm_label
    cm_df.index = cm_label
    return cm_df

# %%
cm_6 = confusionMatrix(pred6,y_test,label)

# %%
cm_6
# Out:
#               axis_11  axis_22  axis_2d2  axis_30  axis_37  axis_3d75
# axis_11             1        0         0        0        0          0  \
# axis_22             0      105         0        0        0          0
# axis_2d2            0        0        34        0        0          0
# axis_30             0        0         0      196        0          0
# axis_37             0        0         0        0      300          0
# axis_3d75           0        0         0        0        0        290
# axis_3d7            0        0         0        0        0          0
# axis_5d5            0        0         0        0        0          0
# axis_7d5            0        0         0        0        0          0
# bearing_11          0        0         0        0        0          0
# bearing_15          0        0         0        0        0          0
# bearing_18d5        0        0         0        0        0          0
# bearing_2d2         0        0         0        0        0          0
# bearing_3d7         0        0         0        0        0          0
# bearing_5d5         0        0         0        0        0          0
# bearing_7d5         0        0         0        0        0          0
# belt_11             0        0         0        0        0          0
# belt_15             0        0         0        0        0          0
# belt_18d5         299        0         0        0        0          0
# belt_22             0      195         0        0        0          0
# belt_2d2            0        0       266        0        0          0
# belt_55             0        0         0      104        0          0
# belt_5d5            0        0         0        0        0         10
# belt_7d5            0        0         0        0        0          0
# normal_11           0        0         0        0        0          0
# normal_15           0        0         0        0        0          0
# normal_18d5         0        0         0        0        0          0
# normal_22           0        0         0        0        0          0
# normal_2d2          0        0         0        0        0          0
# normal_30           0        0         0        0        0          0
# normal_37           0        0         0        0        0          0
# normal_3d75         0        0         0        0        0          0
# normal_3d7          0        0         0        0        0          0
# normal_55           0        0         0        0        0          0
# normal_5d5          0        0         0        0        0          0
# normal_7d5          0        0         0        0        0          0
# rotating_11         0        0         0        0        0          0
# rotating_15         0        0         0        0        0          0
# rotating_22         0        0         0        0        0          0
# rotating_2d2        0        0         0        0        0          0
# rotating_3d7        0        0         0        0        0          0
# rotating_55         0        0         0        0        0          0
# rotating_5d5        0        0         0        0        0          0
#
#               axis_3d7  axis_5d5  axis_7d5  bearing_11  ...  normal_55
# axis_11              0         0         0           0  ...          0  \
# axis_22              0         0         0           0  ...          0
# axis_2d2             0         0         0           0  ...          0
# axis_30              0         0         0           0  ...          0
# axis_37              0         0         0           0  ...          0
# axis_3d75            0         0         0           0  ...          0
# axis_3d7           271         0         0           0  ...          0
# axis_5d5             0       226         0           0  ...          0
# axis_7d5             0         0         0           0  ...          0
# bearing_11           0         0         0         300  ...          0
# bearing_15           0         0         0           0  ...          0
# bearing_18d5         0         0         0           0  ...          0
# bearing_2d2          0         0         0           0  ...          0
# bearing_3d7          0         0         0           0  ...          0
# bearing_5d5          0         0         0           0  ...          0
# bearing_7d5          0         0         0           0  ...          0
# belt_11              0        74         0           0  ...          0
# belt_15              0         0       300           0  ...          0
# belt_18d5            0         0         0           0  ...          0
# belt_22              0         0         0           0  ...          0
# belt_2d2             0         0         0           0  ...          0
# belt_55              0         0         0           0  ...          0
# belt_5d5             0         0         0           0  ...          0
# belt_7d5            29         0         0           0  ...          0
# normal_11            0         0         0           0  ...          0
# normal_15            0         0         0           0  ...          0
# normal_18d5          0         0         0           0  ...          0
# normal_22            0         0         0           0  ...          0
# normal_2d2           0         0         0           0  ...          0
# normal_30            0         0         0           0  ...          0
# normal_37            0         0         0           0  ...          0
# normal_3d75          0         0         0           0  ...          0
# normal_3d7           0         0         0           0  ...          0
# normal_55            0         0         0           0  ...        300
# normal_5d5           0         0         0           0  ...          0
# normal_7d5           0         0         0           0  ...          0
# rotating_11          0         0         0           0  ...          0
# rotating_15          0         0         0           0  ...          0
# rotating_22          0         0         0           0  ...          0
# rotating_2d2         0         0         0           0  ...          0
# rotating_3d7         0         0         0           0  ...          0
# rotating_55          0         0         0           0  ...          0
# rotating_5d5         0         0         0           0  ...          0
# rotating_3d7             0           300            0             0
# rotating_55              0             0          300             0
# rotating_5d5             0             0            0           300
#
# [43 rows x 43 columns]

# %%
cm_6.to_csv("BDJ_ConfusionMatrix/history6_cm.csv")

# %%
import seaborn as sns

# %%
def cm_Heatmap(cm):
    plt.rcParams['axes.unicode_minus'] = False
    get_ipython().run_line_magic('config', "InlineBackend.figure_format='retina'")
    plt.figure(figsize=(35,35))
    sns.heatmap(cm,annot=True,fmt = '.0f',cmap = "PuBuGn",
                annot_kws={"size": 13},linewidths=1)
    sns.set(font_scale=1.8)
    plt.xticks(rotation=40)
    plt.yticks(rotation=0)

# %%
cm_Heatmap(cm_6)

# %%
y_pred_arg = np.argmax(pred6,axis=1)
y_test_arg = np.argmax(y_test,axis=1)
cm_label = DataFrame(encoder.inverse_transform(label))[0].unique()

# %% [markdown]
# ### classification_report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_arg,y_pred_arg, target_names=cm_label))
# Out:
#               precision    recall  f1-score   support
#
#      axis_11       1.00      0.00      0.01       300
#      axis_22       0.45      0.35      0.39       300
#     axis_2d2       0.39      0.11      0.18       300
#      axis_30       0.47      0.65      0.54       300
#      axis_37       1.00      1.00      1.00       300
#    axis_3d75       0.49      0.97      0.65       300
#     axis_3d7       0.48      0.90      0.63       300
#     axis_5d5       0.48      0.75      0.59       300
#     axis_7d5       0.00      0.00      0.00       300
#   bearing_11       1.00      1.00      1.00       300
#   bearing_15       1.00      1.00      1.00       300
# bearing_18d5       1.00      1.00      1.00       300
#  bearing_2d2       1.00      1.00      1.00       300
#  bearing_3d7       1.00      1.00      1.00       300
#  bearing_5d5       1.00      1.00      1.00       300
#  bearing_7d5       1.00      1.00      1.00       300
#      belt_11       0.44      0.20      0.27       300
#      belt_15       0.50      1.00      0.67       300
#    belt_18d5       0.50      1.00      0.67       300
#      belt_22       0.47      0.57      0.51       299
#     belt_2d2       0.48      0.82      0.61       299
#      belt_55       0.42      0.25      0.32       300
#     belt_5d5       0.23      0.01      0.02       300
#     belt_7d5       0.26      0.03      0.06       300
#    normal_11       1.00      1.00      1.00       300
#    normal_15       0.99      1.00      0.99       300
#  normal_18d5       1.00      1.00      1.00       300
#    normal_22       1.00      1.00      1.00       300
#   normal_2d2       1.00      1.00      1.00       300
#    normal_30       1.00      1.00      1.00       300
#    normal_37       1.00      1.00      1.00       300
#  normal_3d75       1.00      1.00      1.00       300
#   normal_3d7       1.00      1.00      1.00       300
#    normal_55       1.00      1.00      1.00       300
#   normal_5d5       1.00      1.00      1.00       300
#   normal_7d5       1.00      1.00      1.00       300
#  rotating_11       1.00      1.00      1.00       300
#  rotating_15       1.00      0.99      0.99       300
#  rotating_22       1.00      1.00      1.00       300
# rotating_2d2       1.00      1.00      1.00       300
# rotating_3d7       1.00      1.00      1.00       300
#  rotating_55       1.00      1.00      1.00       300
# rotating_5d5       1.00      1.00      1.00       300
#
#     accuracy                           0.81     12898
#    macro avg       0.79      0.80      0.77     12898
# weighted avg       0.79      0.81      0.77     12898
