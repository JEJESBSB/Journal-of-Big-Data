# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings("ignore")
# import mglearn
import os.path
import os,re
import glob
import pprint
import pathlib
import threading
import time
import joblib
from pandas import DataFrame
from datetime import datetime,timedelta
import datetime
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
import joblib
from tensorflow import keras
from sklearn.utils import shuffle

# %% [markdown]
# ### Extracting Images

# %%
file_destination = r'C:\Users\SM-PC\BDJ\BDJ_Spectrogram_Testset'
import cv2

image_w = 32
image_h = 32

X = []
Y = []
for f in glob.glob(file_destination + "/*.jpg"):
    img = cv2.imread(f)
    img = cv2.resize(img, (image_w, image_h))
    X.append(img)

# %%
ls = []
for f in os.listdir(file_destination):
#      print((f.split('_')[0:2][0])+'_'+(f.split('_')[0:2][1]))
#     print(f.split('_')[0])
     labels = (f.split('_')[0:2][0])+'_'+(f.split('_')[0:2][1])
     ls.append(labels)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(ls)
label = encoder.transform(ls)
# print the decoded labels
encoder.inverse_transform(label)
# Out:
# array(['axis_11', 'axis_11', 'axis_11', ..., 'rotating_5d5',
#        'rotating_5d5', 'rotating_5d5'], dtype='<U12')

# %%
from keras.utils import np_utils
label_cat = np_utils.to_categorical(label)

# %%
X = np.array(X)
Y = np.array(label_cat)
# print(X,Y)

# %%
X= X.astype("float") / 255.0
X
# Out:
# array([[[[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          ...,
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          [1.        , 1.        , 1.        ]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         ...,
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.32941176, 0.00392157, 0.27058824],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.33333333, 0.01176471, 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.97647059, 1.        , 0.99607843],
#          [0.47058824, 0.35686275, 0.23921569],
#          [0.5254902 , 0.41568627, 0.2627451 ],
#          ...,
#          [0.54901961, 0.56862745, 0.12941176],
#          [0.4627451 , 0.28235294, 0.23921569],
#          [0.97647059, 0.99607843, 0.99215686]],
#
#         [[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          ...,
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [1.        , 1.        , 1.        ]]],
#
#
#        [[[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          ...,
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          [1.        , 1.        , 1.        ]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         ...,
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.32156863, 0.        , 0.2627451 ],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.98039216, 1.        , 1.        ],
#          [0.50588235, 0.36078431, 0.27058824],
#          [0.48235294, 0.35294118, 0.21960784],
#          ...,
#          [0.39215686, 0.21960784, 0.25882353],
#          [0.48627451, 0.34117647, 0.25098039],
#          [0.97254902, 0.99607843, 0.97647059]],
#
#         [[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 0.99607843],
#          ...,
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 1.        ],
#          [1.        , 1.        , 1.        ]]],
#
#
#        [[[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          ...,
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          [1.        , 1.        , 1.        ]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         ...,
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.32941176, 0.00392157, 0.27058824],
#          [0.33333333, 0.00784314, 0.2745098 ],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.97647059, 0.99607843, 0.98823529],
#          [0.56862745, 0.45098039, 0.17254902],
#          [0.49411765, 0.27058824, 0.23137255],
#          ...,
#          [0.49019608, 0.3372549 , 0.27058824],
#          [0.34901961, 0.19607843, 0.23137255],
#          [0.98431373, 1.        , 0.98039216]],
#
#         [[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          ...,
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 0.99607843],
#          [1.        , 1.        , 1.        ]]],
#
#
#        ...,
#
#
#        [[[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          ...,
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          [1.        , 1.        , 1.        ]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         ...,
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.32156863, 0.        , 0.2627451 ],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.98039216, 1.        , 0.99607843],
#          [0.27843137, 0.64313725, 0.68627451],
#          [0.51372549, 0.40784314, 0.18823529],
#          ...,
#          [0.31372549, 0.62745098, 0.47058824],
#          [0.39215686, 0.6       , 0.35294118],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          ...,
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [1.        , 1.        , 1.        ]]],
#
#
#        [[[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          ...,
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          [1.        , 1.        , 1.        ]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         ...,
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.32941176, 0.00392157, 0.27058824],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.32156863, 0.        , 0.2627451 ],
#          [0.32156863, 0.        , 0.2627451 ],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.97254902, 1.        , 0.98039216],
#          [0.49019608, 0.51372549, 0.24705882],
#          [0.43137255, 0.57254902, 0.31764706],
#          ...,
#          [0.45490196, 0.59215686, 0.33333333],
#          [0.40392157, 0.57254902, 0.30588235],
#          [0.98039216, 0.99607843, 0.98039216]],
#
#         [[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          ...,
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [1.        , 1.        , 1.        ]]],
#
#
#        [[[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          ...,
#          [0.99215686, 1.        , 0.99607843],
#          [0.99215686, 1.        , 0.99607843],
#          [1.        , 1.        , 1.        ]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.3254902 , 0.        , 0.26666667],
#          [0.98039216, 1.        , 0.98431373]],
#
#         ...,
#
#         [[0.97647059, 1.        , 0.98039216],
#          [0.32941176, 0.00392157, 0.27058824],
#          [0.32941176, 0.00392157, 0.27058824],
#          ...,
#          [0.3254902 , 0.        , 0.26666667],
#          [0.32941176, 0.00392157, 0.27058824],
#          [0.98039216, 1.        , 0.98431373]],
#
#         [[0.98431373, 1.        , 0.98431373],
#          [0.48627451, 0.51764706, 0.21568627],
#          [0.26666667, 0.63137255, 0.60392157],
#          ...,
#          [0.5254902 , 0.4       , 0.18039216],
#          [0.29803922, 0.6       , 0.60784314],
#          [0.98039216, 0.99607843, 0.99215686]],
#
#         [[1.        , 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          ...,
#          [0.99215686, 1.        , 1.        ],
#          [0.99215686, 1.        , 1.        ],
#          [1.        , 1.        , 1.        ]]]])

# %%
from keras.models import Sequential,Model
from keras.layers import MaxPooling2D,MaxPooling3D,UpSampling2D,Input,Conv2DTranspose
from keras.layers import Conv2D,Conv3D
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.layers import BatchNormalization, Dropout

# %%
from keras.models import load_model
model2_test = keras.models.load_model("BDJ_CNN_Models/history2.h5")

# Print the model summary
model2_test.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 50)        3800
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 50)        62550
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 50)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 100)       125100
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 100)       250100
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 100)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 43)                275243
#
# =================================================================
# Total params: 716,793
# Trainable params: 716,793
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2_test.evaluate(X,Y)
# Out:
# 1344/1344 [==============================] - 6s 2ms/step - loss: 2.6607 - accuracy: 0.7385
# [2.660661220550537, 0.7384651303291321]
